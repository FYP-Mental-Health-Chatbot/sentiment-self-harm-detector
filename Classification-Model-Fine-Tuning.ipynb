# %% [markdown]
# #BERT Fine-Tuning (For Sentiment Analysis & Self-Harm Detection)

# %% [markdown]
# ##Imports Libraries

# %% [markdown]
# ##Load Dataset

# %% [markdown]
# ##Dataset analysis

# %% [markdown]
# ##Preprocessing

# %% [markdown]
# ####Text cleaning

# %% [markdown]
# ####Balance dataset

# %% [markdown]
# ####Encoding

# %% [markdown]
# ####Train Test Split

# %% [markdown]
# ####Tokenization

# %% [markdown]
# ##Fine Model

# %% [markdown]
# ##Evaluation

# %% [markdown]
# ##Save model and Load model
